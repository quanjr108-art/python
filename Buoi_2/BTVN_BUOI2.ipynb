# %%
#bài1
t=int(input("Nhập tháng : "))
while(t<1 or t>12):
    print("Nhập lại")
    t=int(input("Nhập tháng"))
n=int(input("Nhập năm : "))
while(t<0):
    print("Nhâp lại năm ! ")
    n=int(input("Nhập năm : "))
if t==2:
    if n%400==0:
        print(29)
    elif n%4==0 and n%100!=0:
        print(29)
    else:
        print(28)
match t:
    case 4|6|9|11:
        print(30)
    case 1|3|5|7|8|10|12:
        print(31)
# Out:
# Nhập lại
# Nhập lại
# Nhập lại
# 31

# %%
#bài 2
n=int(input("Nhập ngày sinh : "))
t=int(input("Nhập tháng"))
test=1
if t<1 or t>12:
    test=0
    print("Ngày và tháng không hợp lệ")
match t:
    case 2:
        if n>29 or n<1:
            print("Ngày và tháng không hợp lệ !")
            test==0
        elif n>=19:
            print("Song Ngư")
        else:
           print("Bao Binh")     
    case 1|3|5|7|8|10|12:
        if n>31 or n<1:
            print("Ngày và tháng không hợp lệ !")
            test=0
    case 4|6|9|11:
        if n>30 or n<1:
            print("Ngày và tháng không hợp lệ !")
            test=0
if test==1:
    match t:
        case 1: 
            if n>19:
                print("Bảo Bình")
            else:
                print("Ma Kết")     
        case 3: 
            if n>20:
                print("Bạch Dương")
            else:
                print("Song Ngư")     
        case 4: 
            if n>19:
                print("Kim Ngưu")
            else:
                print("Bạch Dương")     
        case 5: 
            if n>20:
                print("Song Tử")
            else:
                print("Kim Ngưu")     
        case 6: 
            if n>20:
                print("Cự Giải")
            else:
                print("Song Tử")     
        case 7: 
            if n>22:
                print("Sư Tử")
            else:
                print("Cự Giải")     
        case 8: 
            if n>22:
                print("Xử Nữ")
            else:
                print("Sư Tử")     
        case 9: 
            if n>22:
                print("Thiên Bình")
            else:
                print("Xử Nữ")     
        case 10: 
            if n>22:
                print("Bọ Cạp")
            else:
                print("Thiên Bình")     
        case 11: 
            if n>21:
                print("Nhân Mã")
            else:
                print("Bọ Cạp")     
        case 12: 
            if n>21:
                print("Ma Kết")
            else:
                print("Nhân Mã")
# Out:
# Xử Nữ

# %%
#bài 3
n=int(input("Nhập số nguyên n "))
s=str(n)
if n<0:
    print('Số chữ số là : {}'.format(len(s)-1))
    tong=0
    for i in range(1,len(s)):
        tong+=int(s[i])
    print('Tong chữ số là : {}'.format(tong))
    print('{} Không phải là số nguyên tố'.format(n))
else:
    print('Số chữ số là : {}'.format(len(s)))
    tong=0
    for i in range(len(s)):
        tong+=int(s[i])
    print('Tổng chữ số là : {}'.format(tong))
    if n<2:
        print('{} Không phải số nguyên tố'.format(n))
    elif n==2:
        print('{} Là số nguyên tố'.format(n))
    else:
        k=0
        for i in range(2,n):
            if n%i==0:
                k=1
                print('{} Không phải là số nguyên tố'.format(n))
                break     
        if k==0:
            print('{} là số nguyên tố'.format(n))
# Out:
# Số chữ số là : 2
# Tổng chữ số là : 9
# 54 Không phải là số nguyên tố

# %%
#bài 4
n=int(input("Nhập số tiền : "))
while n<0:
    print('Nhập lại !')
    n=int(input('Nhập số tiền : '))
m=n//28
if m>=3:
    print('Số chai có thể mua là {} (Mua {}chai ban đầu,dư {} vỏ chai đổi thêm  được {} chai nữa)'.format(m+m//3,m,m,m//3))
else:
    print('So chai bia có thể mua được là : {}'.format(m))
# Out:
# Nhập lại !
# So chai bia có thể mua được là : 0
